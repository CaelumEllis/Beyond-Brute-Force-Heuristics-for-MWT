# %%
import numpy as np


def readCSVForSD(filename) :
    data = np.genfromtxt("results/" + "raw/" + filename, names=True, delimiter=',', dtype=None, encoding='utf-8')
    column_names = data.dtype.names
    sizes = data['size']
    dataset = data['dataset']
    stddevs = data['stddev']
    print("==" + filename + "==")
    print("Dataset | Size | Standard Deviation")
    print("-------------------------")

    for d, s, sd in zip(dataset, sizes, stddevs):
        print(f"{d} | {s} | {sd}")

    print("-------------------------")

def aggregateSizeForSD(filenames):
    alreadyAccessed = [];
    sizeMap = dict()
    for i in filenames:
        data = np.genfromtxt("results/" + "raw/" + i, names=True, delimiter=',', dtype=None, encoding='utf-8')
        column_names = data.dtype.names
        datasets = data['dataset']
        sizes = data['size']
        stddevs = data['stddev']
        for d, s, sd in zip(datasets, sizes, stddevs):
            if d in alreadyAccessed: continue
            s = int(s)
            if (sd == "NO_OUTPUT"): continue
            sd = float(sd)
            if s not in sizeMap:
                sizeMap[s] = []    
            sizeMap[s].append(sd)  
    return sizeMap

def printAggregateSD(sizeDict):
    for size, values in sorted(sizeDict.items()):
        avg = np.mean(values)
        print(f"Size {size}: Average StdDev = {avg}")

# %%
np.set_printoptions(suppress=True)
# readCSVForSD("DT_CES_SA_20251123_050616_9079e4.csv")
# readCSVForSD("DT_CES_SA_20251123_105925_0e2e35.csv")
readCSVForSD("DT_CES_SA_20251123_150032_a59c33.csv")

sizeDict = aggregateSizeForSD(["DT_CES_SA_20251123_150032_a59c33.csv"])
printAggregateSD(sizeDict)
# Out:
# ==DT_CES_SA_20251123_150032_a59c33.csv==
# Dataset | Size | Standard Deviation
# -------------------------
# fractal_1k.pnt | 1000 | 0.0
# fractal_200.pnt | 200 | 0.0
# fractal_25.pnt | 25 | 0.0
# fractal_2k.pnt | 2000 | 0.0
# fractal_3k.pnt | 3000 | 0.0
# fractal_50.pnt | 50 | 0.0
# fractal_500.pnt | 500 | 0.0
# gaussian_10K_D.pnt | 10000 | 0.0
# gaussian_10K_I.pnt | 10000 | 0.0
# gaussian_1k.pnt | 1000 | 0.0
# gaussian_200.pnt | 200 | 0.0
# gaussian_25.pnt | 25 | 0.0
# gaussian_2k.pnt | 2000 | 0.0
# gaussian_3k.pnt | 3000 | 0.0
# gaussian_50.pnt | 50 | 0.0
# gaussian_500.pnt | 500 | 0.0
# GIS_4897_F.pnt | 4897 | NO_OUTPUT
# line_noise_1k.pnt | 1000 | 4.940966504642482
# line_noise_200.pnt | 200 | 7.174989111490025
# line_noise_25.pnt | 25 | 10.364065008479988
# line_noise_2k.pnt | 2000 | 3.7820530139066175
# line_noise_3k.pnt | 3000 | 5.647793263744718
# line_noise_50.pnt | 50 | 3.6502011930851226
# line_noise_500.pnt | 500 | 8.801410043282916
# near_convex_1k.pnt | 1000 | 12.2974712847806
# near_convex_200.pnt | 200 | 16.108225383325205
# near_convex_25.pnt | 25 | 3.2714780680908997
# near_convex_2k.pnt | 2000 | 18.633996484919773
# near_convex_3k.pnt | 3000 | 12.713624581526675
# near_convex_50.pnt | 50 | 11.373900771063589
# near_convex_500.pnt | 500 | 18.66722863737416
# rings_1k.pnt | 1000 | 11.421776076863203
# rings_200.pnt | 200 | 5.188788394220756
# rings_25.pnt | 25 | 2.0
# rings_2k.pnt | 2000 | 14.07309045661261
# rings_3k.pnt | 3000 | 9.97872737376837
# rings_50.pnt | 50 | 11.702437780223402
# rings_500.pnt | 500 | 13.529422567131096
# spiral_1k.pnt | 1000 | 19.432016107444984
# spiral_200.pnt | 200 | 18.287363806738053
# spiral_25.pnt | 25 | 0.15155444566223739
# spiral_2k.pnt | 2000 | 20.33117987230465
# spiral_3k.pnt | 3000 | 39.46519827645668
# spiral_50.pnt | 50 | 5.556434895686275
# spiral_500.pnt | 500 | 13.69335057610076
# U_10K_D.pnt | 10000 | 0.1358160520704368
# U_10K_I.pnt | 10000 | 0.0
# zigzag_1k.pnt | 1000 | 50.15522928867944
# zigzag_200.pnt | 200 | 37.409517087901605
# zigzag_25.pnt | 25 | 12.141098591148927
# zigzag_2k.pnt | 2000 | 33.532830927316546
# zigzag_3k.pnt | 3000 | 43.18913810207371
# zigzag_50.pnt | 50 | 36.84587154621251
# zigzag_500.pnt | 500 | 25.747235773962554
# -------------------------
# Size 1000: Average StdDev = 14.035351323201528
# Size 200: Average StdDev = 12.024126254810806
# Size 25: Average StdDev = 3.9897423019117215
# Size 2000: Average StdDev = 12.9075929650086
# Size 3000: Average StdDev = 15.856354513938594
# Size 50: Average StdDev = 9.875549455181556
# Size 500: Average StdDev = 11.491235371121642
# Size 10000: Average StdDev = 0.0339540130176092
